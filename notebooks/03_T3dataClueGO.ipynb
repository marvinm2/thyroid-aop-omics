# %%
# %pip install py4cytoscape
import py4cytoscape as p4c
import os
import pandas as pd


# Initialize Cytoscape connection
p4c.cytoscape_ping()
# Out:
# Requirement already satisfied: py4cytoscape in /home/marvin/anaconda3/lib/python3.12/site-packages (1.11.0)
# Requirement already satisfied: pandas in /home/marvin/anaconda3/lib/python3.12/site-packages (from py4cytoscape) (2.2.2)
# Requirement already satisfied: networkx in /home/marvin/anaconda3/lib/python3.12/site-packages (from py4cytoscape) (3.2.1)
# Requirement already satisfied: requests in /home/marvin/anaconda3/lib/python3.12/site-packages (from py4cytoscape) (2.32.3)
# Requirement already satisfied: igraph in /home/marvin/anaconda3/lib/python3.12/site-packages (from py4cytoscape) (0.11.8)
# Requirement already satisfied: colorbrewer in /home/marvin/anaconda3/lib/python3.12/site-packages (from py4cytoscape) (0.2.0)
# Requirement already satisfied: chardet in /home/marvin/anaconda3/lib/python3.12/site-packages (from py4cytoscape) (5.2.0)
# Requirement already satisfied: decorator in /home/marvin/anaconda3/lib/python3.12/site-packages (from py4cytoscape) (5.1.1)
# Requirement already satisfied: backoff in /home/marvin/anaconda3/lib/python3.12/site-packages (from py4cytoscape) (2.2.1)
# Requirement already satisfied: colour in /home/marvin/anaconda3/lib/python3.12/site-packages (from py4cytoscape) (0.1.5)
# Requirement already satisfied: six in /home/marvin/anaconda3/lib/python3.12/site-packages (from colorbrewer->py4cytoscape) (1.16.0)
# Requirement already satisfied: texttable>=1.6.2 in /home/marvin/anaconda3/lib/python3.12/site-packages (from igraph->py4cytoscape) (1.7.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/marvin/anaconda3/lib/python3.12/site-packages (from pandas->py4cytoscape) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/marvin/anaconda3/lib/python3.12/site-packages (from pandas->py4cytoscape) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/marvin/anaconda3/lib/python3.12/site-packages (from pandas->py4cytoscape) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/marvin/anaconda3/lib/python3.12/site-packages (from pandas->py4cytoscape) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/marvin/anaconda3/lib/python3.12/site-packages (from requests->py4cytoscape) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/marvin/anaconda3/lib/python3.12/site-packages (from requests->py4cytoscape) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/marvin/anaconda3/lib/python3.12/site-packages (from requests->py4cytoscape) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/marvin/anaconda3/lib/python3.12/site-packages (from requests->py4cytoscape) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# You are connected to Cytoscape!
# 'You are connected to Cytoscape!'

# %%
# Load hypothyroid dataset
hypothyroid_df = pd.read_csv('../data/processed/hypothyroid_condition.csv', sep='\t')

# %%
# Filter for significant genes only, then create nodes
sig_genes = hypothyroid_df[hypothyroid_df['Significance'] == 1].copy()
print(f"Significant genes: {len(sig_genes)}")

nodes = sig_genes[['GeneSymbol', 'log2FC', 'Significance']].copy()
nodes['id'] = nodes['GeneSymbol']  # Assigning ID as GeneSymbol
# Out:
# Significant genes: 2994

# %%
# Convert to list of dictionaries for Cytoscape import
nodes_list = nodes.to_dict('records')

# %%
# Create a network in Cytoscape (without applying layout - will use ClueGO later)
network_suid = p4c.create_network_from_data_frames(nodes=nodes, title='Hypothyroid Network', collection='RNA-Seq Networks')

# Skip layout since ClueGO will be used
print(f"Network created with SUID: {network_suid}")
# Out:
# Applying default style...
# Applying preferred layout
# Network created with SUID: 222753
